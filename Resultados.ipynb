# %% [markdown]
# >## Resultados

# %%
bayes -naive bayes
lazy -ibpk (knn)
trees -j48 (arvore decisão)
trees -randon forest
functions -smo (svm)
functions -multilayer perceptron

# %%
Extrator de contagem RGB, sem filtro
valores = [75.99, 59.0141, 47.8538, 73.8023, 47.3553, 53.2539]

# %%
Extrator de contagem RGB, com filtro
valores = [53.2124, 58.1972, 41.5536, 53.4616, 49.7646, 53.1847]

# %%
Extrator histograma discretizado, sem filtro
valores = [94.6275, 88.9227, 73.8577, 95.126, 81.3487, 86.6934]

# %%
Extrator histograma discretizado, com filtro
valores = [93.8383, 90.3489, 78.3439, 96.026, 80.4902, 85.6273]

# %%
Extrator sift, sem filtro
valores = [72.3622, 72.0438, 71.7668, 78.7178, 77.3331, 77.7209]

# %%
Extrator lbp, sem filtro
valores = [67.9175, 46.566, 46.6076, 67.9036, 42.1351, 47.0645]

# %%
import matplotlib.pyplot as plt

classificadores = ['KNN', 'Árvore de Decisão', 'Naive Bayes', 'Randon Forest', 'SVM', 'Multilayer Perceptron']
v1 = [75.99, 59.0141, 47.8538, 73.8023, 47.3553, 53.2539]
v2 = [53.2124, 58.1972, 41.5536, 53.4616, 49.7646, 53.1847]
v3 = [94.6275, 88.9227, 73.8577, 95.126, 81.3487, 86.6934]
v4 = [93.8383, 90.3489, 78.3439, 96.026, 80.4902, 85.6273]
v5 = [72.3622, 72.0438, 71.7668, 78.7178, 77.3331, 77.7209]
v6 = [67.9175, 46.566, 46.6076, 67.9036, 42.1351, 47.0645]

plt.figure(figsize=(16,8))
plt.plot(classificadores, v1, color='pink', marker='s')
plt.plot(classificadores, v2, color='blue', marker='s')
plt.plot(classificadores, v3, color='gray', marker='s')
plt.plot(classificadores, v4, color='orange', marker='s')
plt.plot(classificadores, v5, color='red', marker='s')
plt.plot(classificadores, v6, color='black', marker='s')

plt.title('Acurácia Obtida por Classificador')
plt.xticks(rotation=30)
plt.legend(['contagem(sf)', 'contagem(cf)', 'histograma(sf)', 'histograma(cf)', 'sift(sf)', 'lbp(sf)'])
plt.show()
